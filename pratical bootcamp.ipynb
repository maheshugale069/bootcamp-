# %%
# Load the Student Performance dataset into a pandas DataFrame. This dataset is available in classroom.  Write code show the first few rows of the dataset.
import pandas as pd    

df = pd.read_csv('student_performance.csv')  
print(df.head())
# Out:
#    StudentID  G1  G2  G3      Mjob     Fjob  age address  studytime  failures  \
# 0          1   6   2   2   teacher  at_home   21   rural          3         1
# 1          2  19  11  18    health  teacher   18   rural          1         1
# 2          3  14   7  19    health    other   20   urban          1         1
# 3          4  10   2   6  services   health   21   urban          3         1
# 4          5   7   0  19    health   health   18   rural          4         1
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0        no    yes  yes        yes     yes    yes       no      yes
# 1        no     no   no         no     yes     no       no       no
# 2       yes    yes  yes         no      no     no      yes      yes
# 3       yes     no  yes         no     yes     no       no       no
# 4        no     no  yes         no     yes    yes      yes       no

# %%
# Write code to display the statistical information on  Student Performance dataset .
import pandas as pd    

df = pd.read_csv('student_performance.csv')   
print("Data Types of Each Column:")
print(df.dtypes)   

print("\nStatistical Summary:") 
print(df.describe())  

print("\nDetailed Information:") 
print(df.info())
# Out:
# Data Types of Each Column:
# StudentID      int64
# G1             int64
# G2             int64
# G3             int64
# Mjob          object
# Fjob          object
# age            int64
# address       object
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# dtype: object
#
# Statistical Summary:
#         StudentID          G1          G2          G3         age  studytime  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.00000
# mean    50.500000    9.010000    8.710000    9.070000   18.180000    2.21000
# std     29.011492    5.535003    6.107282    6.629068    1.940426    1.06643
# min      1.000000    0.000000    0.000000    0.000000   15.000000    1.00000
# 25%     25.750000    4.750000    3.750000    2.000000   16.750000    1.00000
# ...

# %%
# Write code to find number of rows with missing data in the dataset.
import pandas as pd

df = pd.read_csv('tips.csv') 

rows_with_missing_data = df.isnull().sum(axis=1) > 0
num_rows_with_missing_data = rows_with_missing_data.sum()

print(f"Number of rows with missing data: {num_rows_with_missing_data}")
# Out:
# Number of rows with missing data: 0

# %%
import pandas as pd

df = pd.read_csv('student_performance.csv')

print("Data Types of Each Column:")
print(df.dtypes)

print("\nStatistical Summary:")
print(df.describe())

print("\nDetailed Information:")
print(df.info())
# Out:
# Data Types of Each Column:
# StudentID      int64
# G1             int64
# G2             int64
# G3             int64
# Mjob          object
# Fjob          object
# age            int64
# address       object
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# dtype: object
#
# Statistical Summary:
#         StudentID          G1          G2          G3         age  studytime  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.00000
# mean    50.500000    9.010000    8.710000    9.070000   18.180000    2.21000
# std     29.011492    5.535003    6.107282    6.629068    1.940426    1.06643
# min      1.000000    0.000000    0.000000    0.000000   15.000000    1.00000
# 25%     25.750000    4.750000    3.750000    2.000000   16.750000    1.00000
# ...

# %%
# Write code to find mean, mode of the number of runs scored by top 10 players. IPL dataset is available in classroom
import pandas as pd

df = pd.read_csv('ipl_matches_smalldata.csv')

print(df.head())

top_10_players = df[['batter', 'total_runs']].sort_values(by='total_runs', ascending=False).head(10)

mean_runs = top_10_players['total_runs'].mean()
mode_runs = top_10_players['total_runs'].mode()

print(f"Mean of runs scored by top 10 players: {mean_runs}")
print(f"Mode of runs scored by top 10 players: {mode_runs}")
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
# Write code to filter players who have scored more than 500 runs
import pandas as pd

df = pd.read_csv('ipl_matches_smalldata.csv')

print(df.head())

players_above_500_runs = df[df['total_runs'] > 500]

print(players_above_500_runs)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
# code to create a bar chart to visualize the number of runs by top 10 players
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('ipl_matches_smalldata.csv')

print(df.head())

top_10_players = df[['batter', 'total_runs']].sort_values(by='total_runs', ascending=False).head(10)


plt.figure(figsize=(10, 6))
plt.bar(top_10_players['batter'], top_10_players['total_runs'], color='yellow')

plt.xlabel('batter')
plt.ylabel('total_runs')
plt.title('Top 10 Players by Runs Scored')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()  
plt.show()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
# Write a Python program using OpenCV functions to 
# 1. read an image from a file and display it using OpenCV.
# 2. Find the shape (dimensions) of the image. 
# 3. Resize the image to dimensions of 400x256 pixels.
# 4.Display the resized image.
# 5.Flip the image horizontally and vertically
import cv2

image = cv2.imread('mahesh.jpeg')  
if image is None:
    print("Error: Image not found.")
else:

    cv2.imshow('Original Image', image)
    cv2.waitKey(0)  

    height, width, channels = image.shape
    print(f"Original Image Dimensions: {width}x{height} (Width x Height)")

    resized_image = cv2.resize(image, (400, 256))

    cv2.imshow('Resized Image', resized_image)
    cv2.waitKey(0)

    flipped_horizontally = cv2.flip(resized_image, 1) 
    flipped_vertically = cv2.flip(resized_image, 0)  


    cv2.imshow('Flipped Horizontally', flipped_horizontally)
    cv2.imshow('Flipped Vertically', flipped_vertically)
    
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Original Image Dimensions: 377x234 (Width x Height)

# %%
# !pip install wordcloud

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt


nltk.download('punkt')
nltk.download('stopwords')


text = """Artificial Intelligence (AI) is transforming the world. AI includes machine learning, deep learning, 
and natural language processing. AI applications range from chatbots to self-driving cars. AI has great potential 
but also raises ethical concerns."""

tokens = word_tokenize(text.lower())  
filtered_words = [word for word in tokens if word.isalnum() and word not in stopwords.words('english')]


cleaned_text = " ".join(filtered_words)


wordcloud = WordCloud(width=800, height=400, background_color="white").generate(cleaned_text)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud on Artificial Intelligence")
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mahesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mahesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
